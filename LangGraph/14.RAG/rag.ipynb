# %%
from langchain_groq import ChatGroq
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.tools import tool
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_core.messages import HumanMessage, BaseMessage
from langgraph.prebuilt import ToolNode, tools_condition
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model = 'openai/gpt-oss-safeguard-20b')

# %%
loader = PyPDFLoader('intro-to-ml.pdf')
docs = loader.load()

# %%
len(docs)
# Out:
# 392

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 200)
chunks = splitter.split_documents(docs)

# %%
len(chunks)
# Out:
# 973

# %%
embedding_model = HuggingFaceEmbeddings(
    model_name="Qwen/Qwen3-Embedding-4B",
    model_kwargs={
        "device": "cuda", 
        "trust_remote_code": True
    },
    encode_kwargs={"normalize_embeddings": True}
)
vector_store = FAISS.from_documents(chunks,embedding_model)
vector_store.save_local("my_local_faiss_index")
# Out:
# Loading weights: 100%|██████████| 398/398 [00:00<00:00, 3196.06it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 embedding_model = HuggingFaceEmbeddings(
#       2     model_name="Qwen/Qwen3-Embedding-4B",
#       3     model_kwargs={
#       4         "device": "cuda",
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:97, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      94 else:
#      95     model_cls = sentence_transformers.SentenceTransformer
# ---> 97 self._client = model_cls(
#      98     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      99 )
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\sentence_transformers\util\decorators.py:46, in deprecated_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44         else:
#      45             kwargs.pop(old_name)
# ---> 46 return func(*args, **kwargs)
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\sentence_transformers\sentence_transformer\model.py:194, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend, similarity_fn_name, truncate_dim)
#     189         raise ValueError(
#     190             "Both `token` and `use_auth_token` are specified. Please only specify the `token` argument."
#     191         )
#     192     token = use_auth_token
# --> 194 super().__init__(
#     195     model_name_or_path=model_name_or_path,
#     196     modules=modules,
#     197     device=device,
#     198     cache_folder=cache_folder,
#     199     trust_remote_code=trust_remote_code,
#     200     revision=revision,
#     201     local_files_only=local_files_only,
#     202     token=token,
#     203     model_kwargs=model_kwargs,
#     204     processor_kwargs=processor_kwargs,
#     205     config_kwargs=config_kwargs,
#     206     model_card_data=model_card_data,
#     207     backend=backend,
#     208     prompts=prompts,
#     209     default_prompt_name=default_prompt_name,
#     210 )
#     211 self.model_card_data: SentenceTransformerModelCardData
#     213 # Handle INSTRUCTOR models
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\sentence_transformers\base\model.py:275, in BaseModel.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend)
#     273         module.to(backbone_device)
#     274 else:
# --> 275     self.to(device)
#     276 self.is_hpu_graph_enabled = False
#     278 # Validate prompts after model loading (which may have merged config prompts)
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\torch\nn\modules\module.py:1388, in Module.to(self, *args, **kwargs)
#    1385         else:
#    1386             raise
# -> 1388 return self._apply(convert)
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\torch\nn\modules\module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 # _apply is traced by dynamo at the bytecode level, and torch._subclasses
#     936 # is in dynamo's MOD_SKIPLIST, revisit later for c++
#     937 from torch._subclasses.fake_tensor import FakeTensor
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\torch\nn\modules\module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 # _apply is traced by dynamo at the bytecode level, and torch._subclasses
#     936 # is in dynamo's MOD_SKIPLIST, revisit later for c++
#     937 from torch._subclasses.fake_tensor import FakeTensor
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\torch\nn\modules\module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 # _apply is traced by dynamo at the bytecode level, and torch._subclasses
#     936 # is in dynamo's MOD_SKIPLIST, revisit later for c++
#     937 from torch._subclasses.fake_tensor import FakeTensor
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\torch\nn\modules\module.py:966, in Module._apply(self, fn, recurse)
#     962 # Tensors stored in modules are graph leaves, and we don't want to
#     963 # track autograd history of `param_applied`, so we have to use
#     964 # `with torch.no_grad():`
#     965 with torch.no_grad():
# --> 966     param_applied = fn(param)
#     967 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     969 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\torch\nn\modules\module.py:1374, in Module.to.<locals>.convert(t)
#    1367     if convert_to_format is not None and t.dim() in (4, 5):
#    1368         return t.to(
#    1369             device,
#    1370             dtype if t.is_floating_point() or t.is_complex() else None,
#    1371             non_blocking,
#    1372             memory_format=convert_to_format,
#    1373         )
# -> 1374     return t.to(
#    1375         device,
#    1376         dtype if t.is_floating_point() or t.is_complex() else None,
#    1377         non_blocking,
#    1378     )
#    1379 except NotImplementedError as e:
#    1380     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File ~\OneDrive\Desktop\AI Engineering\LangGraph\myvenv\Lib\site-packages\torch\cuda\__init__.py:584, in _lazy_init()
#     579     raise RuntimeError(
#     580         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     581         "multiprocessing, you must use the 'spawn' start method"
#     582     )
#     583 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 584     raise AssertionError("Torch not compiled with CUDA enabled")
#     585 if _cudart is None:
#     586     raise AssertionError(
#     587         "libcudart functions unavailable. It looks like you have a broken build?"
#     588     )
#
# AssertionError: Torch not compiled with CUDA enabled
